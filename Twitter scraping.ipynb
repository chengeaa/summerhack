# %%
import tweepy

# %%
keys = []
with open("keys", "r") as k:
    for line in k:
        keys.append(line)

consumer_key, consumer_secret, access_token, access_token_secret = keys
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# # By user:

# %%
tweets = []
username = 'jack'
count = 100
try: 
# Pulling individual tweets from query
    for tweet in api.user_timeline(id=username, count=count):# Adding to list that contains all tweets
        tweets.append((tweet.created_at,tweet.id,tweet.text))
except BaseException as e:
    print('failed on_status,',str(e))
# Out:
# failed on_status, [{'code': 215, 'message': 'Bad Authentication data.'}]

# %%
tweets
# Out:
# [(datetime.datetime(2020, 6, 6, 2, 25, 54),
#   1269093125336608771,
#   "RT @annkillion: SAY COLIN'S NAME"),
#  (datetime.datetime(2020, 6, 6, 1, 24, 43),
#   1269077730613555201,
#   'RT @AnthonyQuintano: This is what #BlackLivesMatter plaza looks like from above. #blm #georgefloyd #WashingtonDC https://t.co/jjCSJR2c3i'),
#  (datetime.datetime(2020, 6, 6, 1, 22, 12),
#   1269077097294688256,
#   'Not true and not illegal.\n\nThis was pulled because we got a DMCA complaint from copyright holder. https://t.co/RAsaYng71a'),
#  (datetime.datetime(2020, 6, 6, 0, 31, 56),
#   1269064447399616512,
#   'RT @MurielBowser: #BlackLivesMatter https://t.co/OQg6977n5r'),
#  (datetime.datetime(2020, 6, 5, 19, 5, 28),
#   1268982286931775488,
#   'RT @CashApp: The East Oakland Collective is working for justice through organizing community power and supporting the unhoused. Support the…'),
#  (datetime.datetime(2020, 6, 5, 17, 34, 22),
#   1268959362141220865,
# ...

# %% [markdown]
# # By search query
#
# https://tweepy.readthedocs.io/en/latest/api.html#API.search

# %%
result = api.search(q=text_query, count=count, lang='eng')

# %%
result[0].user.screen_name
# Out:
# 'joyequalslove'

# %%
tweets_list = []
text_query = 'COVID'
count = 100
try:
# Pulling individual tweets from query
    for tweet in api.search(q=text_query, count=count, lang='eng'):# Adding to list that contains all tweets
        tweets_list.append((tweet.created_at,tweet.id,tweet.text,tweet.user.screen_name))
except BaseException as e:
    print('failed on_status,',str(e))
tweets_list
# Out:
# [(datetime.datetime(2020, 6, 7, 4, 3, 7),
#   1269479978824957955,
#   'RT @thebookofmormon: “If we get casual about personal acts of private devotion or daily repentance, if we get casual about our scripture st…',
#   'joyequalslove'),
#  (datetime.datetime(2020, 6, 7, 4, 0, 46),
#   1269479388757626880,
#   'RT @thebookofmormon: “If we get casual about personal acts of private devotion or daily repentance, if we get casual about our scripture st…',
#   'Ace93328049'),
#  (datetime.datetime(2020, 6, 7, 4, 0, 34),
#   1269479337775915013,
#   'RT @thebookofmormon: “If we get casual about personal acts of private devotion or daily repentance, if we get casual about our scripture st…',
#   'dunn_baylie'),
#  (datetime.datetime(2020, 6, 7, 3, 53, 40),
#   1269477601862537217,
#   'RT @thebookofmormon: “If we get casual about personal acts of private devotion or daily repentance, if we get casual about our scripture st…',
#   'deseretrose'),
#  (datetime.datetime(2020, 6, 7, 3, 45, 1),
# ...
